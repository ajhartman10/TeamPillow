# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Proj 1/vehicleFARS.csv")
df.head()
# Out:
#    YEAR  ST_CASE  VEH_NO                A_BODY      A_IMP1      A_VROLL  \
# 0  2015    10001       1  Light Truck - Pickup       Front  No Rollover
# 1  2015    10002       1         Passenger Car        Rear     Rollover
# 2  2015    10003       1         Passenger Car       Front     Rollover
# 3  2015    10004       1  Light Truck - Pickup       Front  No Rollover
# 4  2015    10005       1         Passenger Car  Right Side     Rollover
#
#              A_SPVEH  A_MOD_YR A_DRDIS A_DRDRO
# 0  No Speed Involved      2003   Other   Other
# 1     Speed Involved      2006   Other   Other
# 2  No Speed Involved      2008   Other   Other
# 3  No Speed Involved      2005   Other   Other
# 4  No Speed Involved      2006   Other   Other

# %%
df.columns
# Out:
# Index(['YEAR', 'ST_CASE', 'VEH_NO', 'A_BODY', 'A_IMP1', 'A_VROLL', 'A_SPVEH',
#        'A_MOD_YR', 'A_DRDIS', 'A_DRDRO'],
#       dtype='object')

# %%
df = df.rename(
    columns={"VEH_NO": "No_of_Vehicles",
            "A_BODY": "Body_Type",
            "A_IMP1": "Collision_Location",
            "A_VROLL": "Rollover",
            "A_SPVEH": "Speeding",
            "A_MOD_YR": "Model_Year",
            "A_DRDIS": "Distracted_Driver",
            "A_DRDRO": "Drowsy_Driver"})
df.head()
# Out:
#    YEAR  ST_CASE  No_of_Vehicles             Body_Type Collision_Location  \
# 0  2015    10001               1  Light Truck - Pickup              Front
# 1  2015    10002               1         Passenger Car               Rear
# 2  2015    10003               1         Passenger Car              Front
# 3  2015    10004               1  Light Truck - Pickup              Front
# 4  2015    10005               1         Passenger Car         Right Side
#
#       Rollover           Speeding  Model_Year Distracted_Driver Drowsy_Driver
# 0  No Rollover  No Speed Involved        2003             Other         Other
# 1     Rollover     Speed Involved        2006             Other         Other
# 2     Rollover  No Speed Involved        2008             Other         Other
# 3  No Rollover  No Speed Involved        2005             Other         Other
# 4     Rollover  No Speed Involved        2006             Other         Other

# %%
df['Distracted_Driver'] = df['Distracted_Driver'].replace(
    {'Other': 'No', 'Yes - Distracted Driver': 'Yes'})
df.head()
# Out:
#    YEAR  ST_CASE  No_of_Vehicles             Body_Type Collision_Location  \
# 0  2015    10001               1  Light Truck - Pickup              Front
# 1  2015    10002               1         Passenger Car               Rear
# 2  2015    10003               1         Passenger Car              Front
# 3  2015    10004               1  Light Truck - Pickup              Front
# 4  2015    10005               1         Passenger Car         Right Side
#
#       Rollover           Speeding  Model_Year Distracted_Driver Drowsy_Driver
# 0  No Rollover  No Speed Involved        2003                No         Other
# 1     Rollover     Speed Involved        2006                No         Other
# 2     Rollover  No Speed Involved        2008                No         Other
# 3  No Rollover  No Speed Involved        2005                No         Other
# 4     Rollover  No Speed Involved        2006                No         Other

# %%
df['Drowsy_Driver'] = df['Drowsy_Driver'].replace(
    {'Other': 'No', 'Yes - Drowsy Driver': 'Yes'})
df.head()
# Out:
#    YEAR  ST_CASE  No_of_Vehicles             Body_Type Collision_Location  \
# 0  2015    10001               1  Light Truck - Pickup              Front
# 1  2015    10002               1         Passenger Car               Rear
# 2  2015    10003               1         Passenger Car              Front
# 3  2015    10004               1  Light Truck - Pickup              Front
# 4  2015    10005               1         Passenger Car         Right Side
#
#       Rollover           Speeding  Model_Year Distracted_Driver Drowsy_Driver
# 0  No Rollover  No Speed Involved        2003                No            No
# 1     Rollover     Speed Involved        2006                No            No
# 2     Rollover  No Speed Involved        2008                No            No
# 3  No Rollover  No Speed Involved        2005                No            No
# 4     Rollover  No Speed Involved        2006                No            No

# %%
df['Speeding'] = df['Speeding'].replace(
    {'No Speed Involved': 'No', 'Speed Involved': 'Yes'})
df.head()
# Out:
#    YEAR  ST_CASE  No_of_Vehicles             Body_Type Collision_Location  \
# 0  2015    10001               1  Light Truck - Pickup              Front
# 1  2015    10002               1         Passenger Car               Rear
# 2  2015    10003               1         Passenger Car              Front
# 3  2015    10004               1  Light Truck - Pickup              Front
# 4  2015    10005               1         Passenger Car         Right Side
#
#       Rollover Speeding  Model_Year Distracted_Driver Drowsy_Driver
# 0  No Rollover       No        2003                No            No
# 1     Rollover      Yes        2006                No            No
# 2     Rollover       No        2008                No            No
# 3  No Rollover       No        2005                No            No
# 4     Rollover       No        2006                No            No

# %%
df['Rollover'] = df['Rollover'].replace(
    {'No Rollover': 'No', 'Rollover': 'Yes'})
df.head()
# Out:
#    YEAR  ST_CASE  No_of_Vehicles             Body_Type Collision_Location  \
# 0  2015    10001               1  Light Truck - Pickup              Front
# 1  2015    10002               1         Passenger Car               Rear
# 2  2015    10003               1         Passenger Car              Front
# 3  2015    10004               1  Light Truck - Pickup              Front
# 4  2015    10005               1         Passenger Car         Right Side
#
#   Rollover Speeding  Model_Year Distracted_Driver Drowsy_Driver
# 0       No       No        2003                No            No
# 1      Yes      Yes        2006                No            No
# 2      Yes       No        2008                No            No
# 3       No       No        2005                No            No
# 4      Yes       No        2006                No            No

# %%
#type of vehicle
#count of vehicle

# %%
BodyType = df.groupby('Body_Type').count()['YEAR']
BodyType = BodyType.sort_values(ascending=False)
BodyType
# Out:
# Body_Type
# Passenger Car            19534
# Light Truck - Pickup      8698
# Light Truck - Utility     7636
# Motorcycle                5076
# Large Truck               4050
# Light Truck - Van         2172
# Other/Unknown             1327
# Bus                        261
# Light Truck - Other        169
# Name: YEAR, dtype: int64

# %%
BodyType.plot(kind='bar', color='r', align="center")
plt.title("Type of Car for Fatal Crashes")
plt.xlabel("Body Types")
plt.ylabel("Number of Crashes")
# Out:
# Text(0, 0.5, 'Number of Crashes')

# %%
BodyTypedf = pd.DataFrame({"Total Accidents": BodyType}) 
                            
BodyTypedf
# Out:
#                        Total Accidents
# Body_Type
# Passenger Car                    19534
# Light Truck - Pickup              8698
# Light Truck - Utility             7636
# Motorcycle                        5076
# Large Truck                       4050
# Light Truck - Van                 2172
# Other/Unknown                     1327
# Bus                                261
# Light Truck - Other                169

# %%
DrowsyDriver = df.groupby('Drowsy_Driver').count()['YEAR']
DrowsyDriver = DrowsyDriver.sort_values(ascending=False)

DrowsyDriverdf = pd.DataFrame({"Total Accidents": DrowsyDriver}) 
                            
DrowsyDriverdf
# Out:
#                Total Accidents
# Drowsy_Driver
# No                       48187
# Yes                        736

# %%
DrowsyDriver.plot(kind='bar', color='r', align="center")
plt.title("Accidents with a Drowsy Driver")
plt.ylabel("Number of Crashes")
# Out:
# Text(0, 0.5, 'Number of Crashes')

# %%
DistractedDriver = df.groupby('Distracted_Driver').count()['YEAR']
DistractedDriver = DistractedDriver.sort_values(ascending=False)
 
DistractedDriverdf = pd.DataFrame({"Total Accidents": DrowsyDriver}) 
                            
DistractedDriverdf
# Out:
#                Total Accidents
# Drowsy_Driver
# No                       48187
# Yes                        736

# %%
DistractedDriver.plot(kind='bar', color='r', align="center")
plt.title("Accidents with a Distracted Driver")
plt.ylabel("Number of Crashes")
# Out:
# Text(0, 0.5, 'Number of Crashes')

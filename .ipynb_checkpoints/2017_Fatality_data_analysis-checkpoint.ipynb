# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import csv
import os
import numpy as np
from citipy import citipy
import gmaps

# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
#Import datasets
acc_aux_filepath=os.path.join('FARS','FARS2015NationalCSV', 'ACC_AUX_new.csv')
acc_aux_df=pd.read_csv(acc_aux_filepath)
veh_aux_filepath=os.path.join('FARS','FARS2015NationalCSV', 'VEH_AUX_new.csv')
veh_aux_df=pd.read_csv(veh_aux_filepath)
per_aux_filepath=os.path.join('FARS','FARS2015NationalCSV', 'PER_AUX_new.csv')
per_aux_df=pd.read_csv(per_aux_filepath)
acc_aux_df.head(3)
# Out:
#    YEAR    STATE  ST_CASE  LATITUDE  LONGITUD  FATALS  PERSONS  DAY  MONTH  \
# 0  2015  Alabama    10001        34       -87       1        1    1      1
# 1  2015  Alabama    10002        35       -87       1        1    1      1
# 2  2015  Alabama    10003        32       -86       1        2    1      1
#
#    YEAR.1     ...             A_PED      A_PED_F      A_PEDAL    A_PEDAL_F  \
# 0    2015     ...       Other Crash  Other Crash  Other Crash  Other Crash
# 1    2015     ...       Other Crash  Other Crash  Other Crash  Other Crash
# 2    2015     ...       Other Crash  Other Crash  Other Crash  Other Crash
#
#                     A_ROLL     A_POLPUR  \
# 0              Other Crash  Other Crash
# 1  Rollover Involved Crash  Other Crash
# 2  Rollover Involved Crash  Other Crash
#
#                                   A_POSBAC              A_HR       A_DIST  \
# 0   Driver With Positive BAC Testing Crash  No - Hit and Run  Other Crash
# 1  All Drivers With ZERO BAC Testing Crash  No - Hit and Run  Other Crash
# 2   Driver With Positive BAC Testing Crash  No - Hit and Run  Other Crash
#
#       A_DROWSY
# 0  Other Crash
# 1  Other Crash
# 2  Other Crash
#
# [3 rows x 34 columns]

# %%
#Data cleanup - Renaming columns
acc_aux_df = acc_aux_df.loc[:,~acc_aux_df.columns.duplicated()]
acc_aux_df.rename(columns={"YEAR":"year","STATE":"state","LATITUDE":"lat","LONGITUD":"long","FATALS":"fatalities",
                           "PERSONS":"persons","DAY":"day","MONTH":"month","DAY_WEEK":"day_of_week","HOUR":"hour",
                           "MINUTE":"minute","A_TOD":"time_of_day","A_DOW":"weekday","A_REGION":"region",
                           "A_RU":"rural_urban","A_INTER":"interstate","A_INTSEC":"intersection",
                           "A_MANCOL":"manner_of_collision","A_CT":"crash_type","A_LT":"large_truck","A_MC":"motorcycle",
                           "A_SPCRA":"speeding","A_PED":"pedestrian","A_PED_F":"pedestrian_fatality",
                           "A_PEDAL":"pedalcyclist","A_PEDAL_F":"pedalcyclist_fatality","A_ROLL":"rollover",
                           "A_POLPUR":"police_pursuit","A_POSBAC":"bac_test","A_HR":"hit_n_run","A_DIST":"distracted_driver",
                           "A_DROWSY":"drowsy_driver"},inplace=True)
#Remove duplicate column YEAR
acc_aux_df=acc_aux_df.T.drop_duplicates().T
acc_aux_df.head(2)
# Out:
#    year    state ST_CASE lat long fatalities persons day month day_of_week  \
# 0  2015  Alabama   10001  34  -87          1       1   1     1           5
# 1  2015  Alabama   10002  35  -87          1       1   1     1           5
#
#        ...        pedestrian pedestrian_fatality pedalcyclist  \
# 0      ...       Other Crash         Other Crash  Other Crash
# 1      ...       Other Crash         Other Crash  Other Crash
#
#   pedalcyclist_fatality                 rollover police_pursuit  \
# 0           Other Crash              Other Crash    Other Crash
# 1           Other Crash  Rollover Involved Crash    Other Crash
#
#                                   bac_test         hit_n_run  \
# 0   Driver With Positive BAC Testing Crash  No - Hit and Run
# 1  All Drivers With ZERO BAC Testing Crash  No - Hit and Run
#
#   distracted_driver drowsy_driver
# 0       Other Crash   Other Crash
# 1       Other Crash   Other Crash
#
# [2 rows x 33 columns]

# %%
#Data cleanup - Format dataset values for various columns
acc_aux_df['month_name']=acc_aux_df['month'].replace({1:"Jan",2:"Feb",3:"Mar",4:"Apr",5:"May",6:"Jun",7:"Jul",
                                                 8:"Aug",9:"Sep",10:"Oct",11:"Nov",12:"Dec"})

acc_aux_df['day_of_week_name']=acc_aux_df['day_of_week'].replace({1:"Sunday",2:"Monday",3:"Tuesday",4:"Wednesday",
                                                             5:"Thursday",6:"Friday",7:"Saturday"})

acc_aux_df['hour']=acc_aux_df['hour'].replace({99:-1})

acc_aux_df['region'] = acc_aux_df['region'].replace(
    {"Alabama, Florida, Georgia, South Carolina, Tennessee": 'SouthEast', 
     "Alaska, Idaho, Montana, Oregon, Washington": 'PacificNorthWest',
     "Arizona, California, Hawaii":'West',"Arkansas, Iowa, Kansas, Missouri, Nebraska":'Midwest',
     "Illinois, Indiana, Michigan, Minnesota, Ohio, Wisconsin":'North',
     "Colorado, Nevada, North Dakota, South Dakota, Utah, Wyoming":'Mountain',
     "Connecticut, Maine, Massachusetts, New Hampshire, Rhode Island, Vermont":'NorthEast',
     "Louisiana, Mississippi, New Mexico, Oklahoma, Texas":'South',
     "Delaware, District of Columbia, Kentucky, Maryland, North Carolina, Virginia, West Virginia":'East',
     "New Jersey, New York, Pennsylvania, Puerto Rico":'NorthEast'})

acc_aux_df['manner_of_collision']=acc_aux_df['manner_of_collision'].replace(
    {"Not Collision with Motor Vehicle in Transport":'Single-vehicle-crash',
     "Other":'Miscellaneous',
     "Unknown":'Miscellaneous'})

acc_aux_df['large_truck']=acc_aux_df['large_truck'].replace({"Other Crash":"No","Large Truck Involved Crash":"Yes"})
acc_aux_df['motorcycle']=acc_aux_df['motorcycle'].replace({"Other Crash":"No","Motorcycle Involved Crash":"Yes"})
acc_aux_df['speeding']=acc_aux_df['speeding'].replace({"Other Crash":"No","Speeding Involved Crash":"Yes"})
acc_aux_df['pedestrian']=acc_aux_df['pedestrian'].replace({"Other Crash":"No","Pedestrian Involved Crash":"Yes"})
acc_aux_df['pedestrian_fatality']=acc_aux_df['pedestrian_fatality'].replace({"Other Crash":"No",
                                                                             "Pedestrian Fatality Involved Crash":"Yes"})
acc_aux_df['pedalcyclist']=acc_aux_df['pedalcyclist'].replace({"Other Crash":"No","Pedalcyclist Involved Crash":"Yes"})
acc_aux_df['pedalcyclist_fatality']=acc_aux_df['pedalcyclist_fatality'].replace({"Other Crash":"No",
                                                                                 "Pedalcyclist Fatality Involved Crash":"Yes"})
acc_aux_df['rollover']=acc_aux_df['rollover'].replace({"Other Crash":"No","Rollover Involved Crash":"Yes"})
acc_aux_df['police_pursuit']=acc_aux_df['police_pursuit'].replace({"Other Crash":"No",
                                                                   "Police Pursuit Involved Crash":"Yes"})
acc_aux_df['hit_n_run']=acc_aux_df['hit_n_run'].replace({"No - Hit and Run":"No","Yes - Hit and Run":"Yes"})
acc_aux_df['distracted_driver']=acc_aux_df['distracted_driver'].replace({"Other Crash":"No",
                                                                         "Involving a Distracted Driver":"Yes"})
acc_aux_df['drowsy_driver']=acc_aux_df['drowsy_driver'].replace({"Other Crash":"No","Involving a Drowsy Driver":"Yes"})

acc_aux_df['lat']=acc_aux_df['lat'].replace(100,np.nan)
acc_aux_df['long']=acc_aux_df['long'].replace({778:np.nan,889:np.nan})
acc_aux_df.dropna(subset=['lat','long'])
# Out:
#        year    state ST_CASE   lat   long fatalities persons day month  \
# 0      2015  Alabama   10001  34.0  -87.0          1       1   1     1
# 1      2015  Alabama   10002  35.0  -87.0          1       1   1     1
# 2      2015  Alabama   10003  32.0  -86.0          1       2   1     1
# 3      2015  Alabama   10004  31.0  -86.0          1       1   4     1
# 4      2015  Alabama   10005  31.0  -86.0          1       2   7     1
# 5      2015  Alabama   10006  33.0  -85.0          1       2   8     1
# 6      2015  Alabama   10007  35.0  -87.0          1       2   8     1
# 7      2015  Alabama   10008  33.0  -87.0          1       1   3     1
# 8      2015  Alabama   10009  33.0  -87.0          1       1  13     1
# 9      2015  Alabama   10010  35.0  -88.0          1       2   5     1
# 10     2015  Alabama   10011  35.0  -87.0          1       2   7     1
# 11     2015  Alabama   10012  34.0  -86.0          1       6   9     1
# 12     2015  Alabama   10013  33.0  -86.0          1       1  10     1
# 13     2015  Alabama   10014  32.0  -86.0          1       1  11     1
# 14     2015  Alabama   10015  34.0  -88.0          1       1  11     1
# 15     2015  Alabama   10016  33.0  -85.0          1       2  13     1
# 16     2015  Alabama   10017  31.0  -88.0          1       1  14     1
# 17     2015  Alabama   10018  33.0  -87.0          1       2  16     1
# 18     2015  Alabama   10019  33.0  -86.0          1       1  19     1
# 19     2015  Alabama   10020  33.0  -86.0          1       3  15     1
# 20     2015  Alabama   10021  34.0  -87.0          1       4  23     1
# 21     2015  Alabama   10022  34.0  -87.0          1       2  26     1
# 22     2015  Alabama   10023  32.0  -86.0          1       1  12     1
# 23     2015  Alabama   10024  32.0  -85.0          1       1   2     1
# 24     2015  Alabama   10025  33.0  -88.0          2       2  15     1
# 25     2015  Alabama   10026  33.0  -87.0          1       1  13     1
# 26     2015  Alabama   10027  30.0  -88.0          1       3  17     1
# 27     2015  Alabama   10028  32.0  -87.0          1       1  10     1
# 28     2015  Alabama   10029  31.0  -85.0          1       1  23     1
# 29     2015  Alabama   10030  33.0  -86.0          5       5  24     1
# ...     ...      ...     ...   ...    ...        ...     ...  ..   ...
# 32136  2015  Wyoming  560101  43.0 -106.0          1       2  18     9
# 32137  2015  Wyoming  560102  44.0 -105.0          1       2  19     9
# 32138  2015  Wyoming  560103  43.0 -106.0          1       1  30     9
# 32139  2015  Wyoming  560104  43.0 -106.0          1       2   3    10
# 32140  2015  Wyoming  560105  41.0 -105.0          1       1  10    10
# 32141  2015  Wyoming  560106  43.0 -105.0          1       1  10    10
# 32142  2015  Wyoming  560107  41.0 -107.0          1       1  17    10
# 32143  2015  Wyoming  560108  42.0 -106.0          1       1  19    10
# 32144  2015  Wyoming  560109  43.0 -106.0          1       2  22    10
# 32145  2015  Wyoming  560110  42.0 -110.0          1       2  25    10
# 32146  2015  Wyoming  560111  44.0 -108.0          1       1  22    10
# 32147  2015  Wyoming  560112  43.0 -108.0          1       2  31    10
# 32148  2015  Wyoming  560113  43.0 -106.0          1       1  27    10
# 32149  2015  Wyoming  560114  44.0 -106.0          1       2   3    11
# 32150  2015  Wyoming  560115  43.0 -109.0          2       3  10    11
# 32151  2015  Wyoming  560116  43.0 -105.0          2       2   5    11
# 32152  2015  Wyoming  560117  43.0 -107.0          2       2  11    11
# 32153  2015  Wyoming  560118  42.0 -105.0          1       1  14    11
# 32154  2015  Wyoming  560119  43.0 -108.0          1       2  14    11
# 32155  2015  Wyoming  560120  41.0 -110.0          1       2   3    11
# 32156  2015  Wyoming  560121  43.0 -106.0          1       2   6    11
# 32157  2015  Wyoming  560122  42.0 -109.0          1       2  19    11
# 32158  2015  Wyoming  560123  43.0 -111.0          1       2  23    11
# 32159  2015  Wyoming  560124  45.0 -107.0          1       5  24    11
# 32160  2015  Wyoming  560125  42.0 -106.0          1       2   6    12
# 32161  2015  Wyoming  560126  43.0 -107.0          2       2   9    12
# 32162  2015  Wyoming  560127  41.0 -105.0          1       3  10    12
# 32163  2015  Wyoming  560128  41.0 -105.0          1       2  13    12
# 32164  2015  Wyoming  560129  42.0 -104.0          1       4  14    12
# 32165  2015  Wyoming  560130  45.0 -107.0          1       1  19    12
#
#       day_of_week       ...         pedalcyclist pedalcyclist_fatality  \
# 0               5       ...                   No                    No
# 1               5       ...                   No                    No
# 2               5       ...                   No                    No
# 3               1       ...                   No                    No
# 4               4       ...                   No                    No
# 5               5       ...                   No                    No
# 6               5       ...                   No                    No
# 7               7       ...                   No                    No
# 8               3       ...                   No                    No
# 9               2       ...                   No                    No
# 10              4       ...                   No                    No
# 11              6       ...                   No                    No
# 12              7       ...                   No                    No
# 13              1       ...                   No                    No
# 14              1       ...                   No                    No
# 15              3       ...                   No                    No
# 16              4       ...                   No                    No
# 17              6       ...                   No                    No
# 18              2       ...                   No                    No
# 19              5       ...                   No                    No
# 20              6       ...                   No                    No
# 21              2       ...                   No                    No
# 22              2       ...                   No                    No
# 23              6       ...                   No                    No
# 24              5       ...                   No                    No
# 25              3       ...                   No                    No
# 26              7       ...                   No                    No
# 27              7       ...                   No                    No
# 28              6       ...                   No                    No
# 29              7       ...                   No                    No
# ...           ...       ...                  ...                   ...
# 32136           6       ...                   No                    No
# 32137           7       ...                   No                    No
# 32138           4       ...                   No                    No
# 32139           7       ...                   No                    No
# 32140           7       ...                   No                    No
# 32141           7       ...                   No                    No
# 32142           7       ...                   No                    No
# 32143           2       ...                   No                    No
# 32144           5       ...                   No                    No
# 32145           1       ...                   No                    No
# 32146           5       ...                   No                    No
# 32147           7       ...                   No                    No
# 32148           3       ...                   No                    No
# 32149           3       ...                   No                    No
# 32150           3       ...                   No                    No
# 32151           5       ...                   No                    No
# 32152           4       ...                   No                    No
# 32153           7       ...                   No                    No
# 32154           7       ...                   No                    No
# 32155           3       ...                   No                    No
# 32156           6       ...                   No                    No
# 32157           5       ...                   No                    No
# 32158           2       ...                   No                    No
# 32159           3       ...                   No                    No
# 32160           1       ...                   No                    No
# 32161           4       ...                   No                    No
# 32162           5       ...                   No                    No
# 32163           1       ...                   No                    No
# 32164           2       ...                   No                    No
# 32165           7       ...                   No                    No
#
#       rollover police_pursuit                                 bac_test  \
# 0           No             No   Driver With Positive BAC Testing Crash
# 1          Yes             No  All Drivers With ZERO BAC Testing Crash
# 2          Yes             No   Driver With Positive BAC Testing Crash
# 3           No             No   Driver With Positive BAC Testing Crash
# 4          Yes             No  All Drivers With ZERO BAC Testing Crash
# 5          Yes             No                        Unknown BAC Crash
# 6           No             No                        Unknown BAC Crash
# 7           No             No                        Unknown BAC Crash
# 8          Yes             No                        Unknown BAC Crash
# 9           No             No                        Unknown BAC Crash
# 10         Yes             No  All Drivers With ZERO BAC Testing Crash
# 11          No             No                        Unknown BAC Crash
# 12         Yes             No   Driver With Positive BAC Testing Crash
# 13         Yes             No   Driver With Positive BAC Testing Crash
# 14         Yes             No  All Drivers With ZERO BAC Testing Crash
# 15          No             No                        Unknown BAC Crash
# 16          No             No  All Drivers With ZERO BAC Testing Crash
# 17          No             No   Driver With Positive BAC Testing Crash
# 18         Yes             No  All Drivers With ZERO BAC Testing Crash
# 19          No             No                        Unknown BAC Crash
# 20          No             No                        Unknown BAC Crash
# 21         Yes             No                        Unknown BAC Crash
# 22          No             No                        Unknown BAC Crash
# 23          No             No                        Unknown BAC Crash
# 24          No             No   Driver With Positive BAC Testing Crash
# 25         Yes             No                        Unknown BAC Crash
# 26         Yes             No                        Unknown BAC Crash
# 27         Yes             No   Driver With Positive BAC Testing Crash
# 28          No             No                        Unknown BAC Crash
# 29         Yes             No  All Drivers With ZERO BAC Testing Crash
# ...        ...            ...                                      ...
# 32136      Yes             No   Driver With Positive BAC Testing Crash
# 32137      Yes             No  All Drivers With ZERO BAC Testing Crash
# 32138       No             No   Driver With Positive BAC Testing Crash
# 32139       No             No   Driver With Positive BAC Testing Crash
# 32140      Yes             No                        Unknown BAC Crash
# 32141      Yes             No   Driver With Positive BAC Testing Crash
# 32142      Yes             No   Driver With Positive BAC Testing Crash
# 32143      Yes             No   Driver With Positive BAC Testing Crash
# 32144       No             No                        Unknown BAC Crash
# 32145      Yes             No  All Drivers With ZERO BAC Testing Crash
# 32146      Yes             No   Driver With Positive BAC Testing Crash
# 32147      Yes             No   Driver With Positive BAC Testing Crash
# 32148      Yes             No                        Unknown BAC Crash
# 32149      Yes             No  All Drivers With ZERO BAC Testing Crash
# 32150      Yes             No   Driver With Positive BAC Testing Crash
# 32151      Yes            Yes                        Unknown BAC Crash
# 32152      Yes             No   Driver With Positive BAC Testing Crash
# 32153       No             No  All Drivers With ZERO BAC Testing Crash
# 32154      Yes             No   Driver With Positive BAC Testing Crash
# 32155      Yes             No   Driver With Positive BAC Testing Crash
# 32156       No             No                        Unknown BAC Crash
# 32157      Yes             No   Driver With Positive BAC Testing Crash
# 32158       No             No                        Unknown BAC Crash
# 32159      Yes             No                        Unknown BAC Crash
# 32160      Yes             No                        Unknown BAC Crash
# 32161       No             No                        Unknown BAC Crash
# 32162      Yes             No                        Unknown BAC Crash
# 32163      Yes             No                        Unknown BAC Crash
# 32164       No             No                        Unknown BAC Crash
# 32165      Yes             No                        Unknown BAC Crash
#
#       hit_n_run distracted_driver drowsy_driver month_name day_of_week_name
# 0            No                No            No        Jan         Thursday
# 1            No                No            No        Jan         Thursday
# 2            No                No            No        Jan         Thursday
# 3            No                No            No        Jan           Sunday
# 4            No                No            No        Jan        Wednesday
# 5            No                No            No        Jan         Thursday
# 6            No                No            No        Jan         Thursday
# 7           Yes                No            No        Jan         Saturday
# 8            No                No            No        Jan          Tuesday
# 9            No                No            No        Jan           Monday
# 10           No                No            No        Jan        Wednesday
# 11           No                No           Yes        Jan           Friday
# 12           No                No            No        Jan         Saturday
# 13           No                No            No        Jan           Sunday
# 14           No                No            No        Jan           Sunday
# 15           No                No            No        Jan          Tuesday
# 16           No                No            No        Jan        Wednesday
# 17           No                No            No        Jan           Friday
# 18           No                No            No        Jan           Monday
# 19           No                No            No        Jan         Thursday
# 20           No               Yes            No        Jan           Friday
# 21           No                No           Yes        Jan           Monday
# 22           No                No            No        Jan           Monday
# 23           No                No           Yes        Jan           Friday
# 24           No                No            No        Jan         Thursday
# 25           No                No            No        Jan          Tuesday
# 26           No                No            No        Jan         Saturday
# 27           No                No            No        Jan         Saturday
# 28           No                No            No        Jan           Friday
# 29           No                No            No        Jan         Saturday
# ...         ...               ...           ...        ...              ...
# 32136        No                No            No        Sep           Friday
# 32137        No               Yes            No        Sep         Saturday
# 32138        No                No            No        Sep        Wednesday
# 32139        No               Yes            No        Oct         Saturday
# 32140        No                No           Yes        Oct         Saturday
# 32141        No                No           Yes        Oct         Saturday
# 32142        No                No            No        Oct         Saturday
# 32143        No                No            No        Oct           Monday
# 32144        No                No            No        Oct         Thursday
# 32145        No               Yes            No        Oct           Sunday
# 32146        No                No            No        Oct         Thursday
# 32147        No               Yes            No        Oct         Saturday
# 32148        No                No            No        Oct          Tuesday
# 32149        No                No            No        Nov          Tuesday
# 32150        No                No            No        Nov          Tuesday
# 32151        No                No            No        Nov         Thursday
# 32152        No                No            No        Nov        Wednesday
# 32153        No                No            No        Nov         Saturday
# 32154        No                No            No        Nov         Saturday
# 32155        No                No            No        Nov          Tuesday
# 32156        No                No            No        Nov           Friday
# 32157        No                No            No        Nov         Thursday
# 32158        No                No            No        Nov           Monday
# 32159        No                No           Yes        Nov          Tuesday
# 32160        No                No            No        Dec           Sunday
# 32161        No                No            No        Dec        Wednesday
# 32162        No                No            No        Dec         Thursday
# 32163        No               Yes            No        Dec           Sunday
# 32164        No                No            No        Dec           Monday
# 32165        No                No            No        Dec         Saturday
#
# [31959 rows x 35 columns]

# %%
#Using citipy, find nearest city based on lattitude and longitude
acc_aux_df['closest_city'] =[(citipy.nearest_city(acc_aux_df['lat'][x], 
                                                  acc_aux_df['long'][x])
                                    .city_name) for x in range(len(acc_aux_df.ST_CASE))]

#Calculate fatality rate for each case
acc_aux_df['fatality_rate'] = [(acc_aux_df['fatalities'][y]/(acc_aux_df['persons'][y]+.000000001)) 
                               for y in range(len(acc_aux_df['ST_CASE']))]

# %%
acc_aux_df['state'].value_counts().plot(kind='bar',figsize=(15,5))
plt.title('Accidents by State')
plt.show()

# %%
acc_aux_df['crash_type'].value_counts().plot(kind='barh')
plt.title('Accidents by crash type')
plt.ylabel("Crash Type")
plt.xlabel("Number of accidents")
plt.show()

# %%
acc_aux_df['month_name'].value_counts().plot(kind='barh',figsize=(8,5))
plt.title('Accidents by Month')
plt.show()

# %%
acc_aux_df['day_of_week'].value_counts().plot(kind='barh',figsize=(8,5))
plt.title('Accidents by day of the week')
plt.show()

# %%
acc_aux_df['region'].value_counts().plot(kind='pie',figsize=(7,7),autopct='%.2f',legend=False)
plt.title('Distribution of accidents across region')
plt.show()

# %%
acc_aux_df['manner_of_collision'].value_counts().plot(kind='pie',figsize=(7,7),autopct='%.2f',legend=False)
plt.title('Distribution of manner of collision')
plt.show()

# %%
veh_aux_df['A_BODY'].value_counts().plot(kind='bar',figsize=(7,7))
plt.title('Accidents by vehicle type')
plt.show()

# %%
#Cleaning records with null lat or long 
acc_aux_df_cleaned=acc_aux_df.dropna(subset=['lat','long'])

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(acc_aux_df_cleaned[["lat", "long"]], weights=acc_aux_df_cleaned["fatalities"], 
                                 dissipating=False, max_intensity=300,
                                 point_radius=1)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Plot a graph of total number of fatalities by months
acc_aux_df_cleaned.groupby('month')['fatalities'].sum().plot(subplots=False,figsize=(8,4))
plt.title('Total fatalities by month')
# Out:
# Text(0.5,1,'Total fatalities by month')

# %%
#Plot a graph of total number of fatalities by region and month 
plt.figure()
acc_aux_df_cleaned.groupby(['month','region'])['ST_CASE'].count().unstack().plot(subplots=False,figsize=(10,6))
plt.title('Total fatalities by month and region')
plt.ylabel('fatality count')
plt.show()

# %%
#Boxplot by region
acc_aux_df_cleaned.boxplot(column='hour',by='region',figsize=(10,5))
plt.ylabel('hour of day')
plt.show()
